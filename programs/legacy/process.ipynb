# %%
# %load_ext autoreload
# %autoreload 2

# %%
import collections
import re
from Levenshtein import distance, ratio
from tfFromTsv import convert, loadTf
from tf.app import use
from hocr import Hocr

# %%
H = Hocr(4)

# %%
H.simplify()
# Out:
# Simplifying HOCR source
# All lines recognized
# OK

# %%
H.read()
# Out:
# Reading HOCR simplified source
#      18 spaces with width  0
#     147 spaces with width 10
#   13438 spaces with width 20
#   12243 spaces with width 30
#   53049 spaces with width 40
#   85050 spaces with width 50
#   13765 spaces with width 60
#   38341 spaces with width 70
#    2801 spaces with width 80
#     722 spaces with width 90
#      71 spaces with width 100
#      23 spaces with width 110
#       7 spaces with width 120
#       4 spaces with width 140
#       6 spaces with width 150
#       1 spaces with width 160
#       4 spaces with width 190
#     737 spaces with width 200
# Inhibited 58 word boundaries after a thin space of <= 9 px
# Statistics:
# photo     :       8 x skipped
# table     :       1 x ignored
# tr        :       1 x ignored
# td        :       3 x changed to area
# page      :     529 x
# area      :    1785 x
# para      :    6840 x
# line      :   24052 x
# word      :  240148 x
# char      : 1528934 x minus 58 = 1528876
# ...

# %%
H.wordify()
# Out:
# Chunking characters into words
# 240148 raw words
# 55 word joins:
# line      17: bef + ore
# line     435: any + where
# line     531: half + of
# line    1015: dagelij + ksche
# line    1017: o + f
# line    1661: Par + sta,
# line    3780: bat + talie
# line    4390: uyt + val
# line   10838: on + verhandelde
# line   16922: daer + van
# line   20109: uyt + vallen
# line   20569: namen + tlyck
# line   20990: voornamen + tlyck
# line   22158: schoof + en
# line   24399: vertreek + t
# line   24641: Ha + tips
# line   34538: Sant + voort,
# line   34826: Buy + ren
# line   44239: namen + tlyck
# line   48179: f + ondergebracht
# line   52984: soo + veel
# line   55549: (uy + tgesondert
# line   57453: by + gelegene
# line   61031: brieff + ken
# line   61414: veltovers + ten
# line   68286: f + synen
# line   74551: Geinven + teerde
# line   83144: gearriveerrt + jacht
# line   87517: Ad + vis
# line   90185: ca + villatien
# line   96288: sieck + te,
# line   96357: uy + tgeseth
# ...

# %%
H.clean()
# Out:
# Removing
#             * The pages before page 14
#             * The pages after page 496
#             * the strings Digitized by Google at the bottom of each page
#             Saving and removing
#             * The header lines of each page
# Head analysis:
# 138	R	XX-CONT-D	1640	12	21	21	21  DFCEMBER.  128
# Head analysis overview:
# 	   1 pages: XX
# 	   1 pages: XX-CONT-D
# 	 481 pages: OK
# Missed 'Digitized by Google' 0 x
# Deleted 'Digitized by Google' 483 x
# Separated 1536 words in 483 header lines
# 226726 words
# Not counting 13422 skipped words
# Did all other words make it into the word records? True

# %%
H.write()
# Out:
# Writing word file as tsv: ~/github/clariah/wp6-daghregisters/_local/daghregister004_words.tsv
# Writing head line file as tsv: ~/github/clariah/wp6-daghregisters/aux/daghregister/004/heads.tsv

# %%
convert(4)
# Out:
# This is Text-Fabric 9.2.0
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 13 features found and 0 ignored
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    volume, page, line
#    |   SECTION   FEATURES: n, n, n
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-full       letters, punc
#    |     0.00s OK
#    |     0.00s Following director...
#    |     1.78s "edge" actions: 0
#    |     1.78s "feature" actions: 255253
#    |     1.78s "node" actions: 24968
#    |     1.78s "resume" actions: 0
#    |     1.78s "slot" actions: 229055
#    |     1.78s "terminate" actions: 24971
#    |      20291 x "line" node
#    |        483 x "page" node
#    |       4193 x "para" node
#    |          1 x "volume" node
#    |     229055 x "word" node  = slot type
# ...

# %%
TF = loadTf(4)
# Out:
# Loading tf data from ~/github/clariah/wp6-daghregisters/tf/daghregister/004/0.1
#    |     0.11s T otype                from ~/github/clariah/wp6-daghregisters/tf/daghregister/004/0.1
#    |     0.79s T oslots               from ~/github/clariah/wp6-daghregisters/tf/daghregister/004/0.1
#   0.90s Dataset without structure sections in otext:no structure functions in the T-API
#    |     1.12s T punc                 from ~/github/clariah/wp6-daghregisters/tf/daghregister/004/0.1
#    |     0.10s T n                    from ~/github/clariah/wp6-daghregisters/tf/daghregister/004/0.1
#    |     1.29s T letters              from ~/github/clariah/wp6-daghregisters/tf/daghregister/004/0.1
#    |      |     0.01s C __levels__           from otype, oslots, otext
#    |      |     1.32s C __order__            from otype, oslots, __levels__
#    |      |     0.08s C __rank__             from otype, __order__
#    |      |     1.92s C __levUp__            from otype, oslots, __rank__
# ...

# %%
A = use("clariah/wp6-daghregisters:clone", checkout="clone", version="0.1", hoist=globals())
# Out:
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/clariah/wp6-daghregisters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/clariah/wp6-daghregisters/tf/daghregister/004/0.1</span>
# This is Text-Fabric 9.2.0
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 13 features found and 0 ignored
# ...

# %% [markdown]
# Check for irregular headers

# %%
query = """
page year=1640 month=11 dayfrom>15 dayfrom<20
"""

# %%
results = A.search(query)
# Out:
#   0.00s 9 results

# %%
A.table(results)
# Out:
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">page</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr">4 76</span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu "><span class="tfsechead ltr"><span class="ltr">4 76</span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr">4 77</span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu "><span class="tfsechead ltr"><span class="ltr">4 77</span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">3</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr">4 78</span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu "><span class="tfsechead ltr"><span class="ltr">4 78</span></span></span></span></td></tr>
# ...

# %%
query = """
page year=1640 month=11 dayfrom<20
"""

# %%
results = A.search(query)
# Out:
#   0.00s 9 results

# %%
A.table(results)
# Out:
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">page</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr">4 76</span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu "><span class="tfsechead ltr"><span class="ltr">4 76</span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr">4 77</span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu "><span class="tfsechead ltr"><span class="ltr">4 77</span></span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">3</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr">4 78</span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu "><span class="tfsechead ltr"><span class="ltr">4 78</span></span></span></span></td></tr>
# ...
